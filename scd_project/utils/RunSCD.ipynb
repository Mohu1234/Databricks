# %%
# Cell 1: Import and run
import sys
sys.path.append("/Workspace/Users/mohu.tera@gmail.com/scd_project")

from utils.scd_job_runner import run_scd_job

# Run for single table (product_current)
results = run_scd_job(
    spark, 
    "/Workspace/Users/mohu.tera@gmail.com/scd_project/configs/scd_tables.yaml"
)

print(f"\n✅ Job completed!")
print(f"Tables processed: {results['tables_processed']}")
print(f"Succeeded: {results['tables_succeeded']}")
print(f"Failed: {results['tables_failed']}")
